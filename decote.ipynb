# %%
import pandas as pd

# %%
df_vinted=pd.read_csv('vinted_data_clean.csv')
df_zara=pd.read_csv('zara_data_clean.csv')

# %%
def prix_moyen_zara(categorie, collection, couleur, matiere):

    """
    Renvoie le prix moyen Zara neuf correspondant aux critères donnés.
    
    niveaux de filtrage :
    1. catégorie + collection + couleur + matière
    2. catégorie + collection + couleur
    3. catégorie + collection
    4. catégorie
    """
    df = df_zara.copy()

    # Niveau 1 : tous les critères
    filtre = (
        (df['categorie'] == categorie) &
        (df['collection'] == collection) &
        (df['matiere'] == matiere)
    )

    resultats = df[filtre]

    if len(resultats) > 0:
        print('niveau 1')
        return resultats['prix'].mean()
    else:

        # Niveau 2 : sans la matière
        filtre = (
            (df['categorie'] == categorie) &
            (df['collection'] == collection) &
            (df['couleur'] == couleur)
        )

        resultats = df[filtre]

        if len(resultats) > 0:
            return resultats['prix'].mean()
        else:
            # Niveau 3 : sans la matière ni la couleur
            filtre = (
                (df['categorie'] == categorie) &
                (df['collection'] == collection)
            )

            resultats = df[filtre]

            if len(resultats) > 0:
                return resultats['prix'].mean()
                
            else:
                return df[df['collection'] == collection]['prix'].mean()

# %%
def prix_moyen_zara(categorie, collection, couleur, matiere):

    """
    Renvoie le prix moyen Zara neuf correspondant aux critères donnés.
    
    niveaux de filtrage :
    1. catégorie + collection + couleur + matière
    2. catégorie + collection + couleur
    3. catégorie + collection
    4. catégorie
    """
    df = df_zara.copy()

    # Niveau 1 : tous les critères
    filtre = (
        (df['categorie'] == categorie) &
        (df['collection'] == collection) &
        (df['matiere'] == matiere)
    )
    i=1
    resultats = df[filtre]

    if len(resultats) == 0:
        filtre = (
            (df['categorie'] == categorie) &
            (df['collection'] == collection) &
            (df['couleur'] == couleur)
        )
        i+=1
        resultats = df[filtre]

        if len(resultats) == 0:
            filtre = (
                (df['categorie'] == categorie) &
                (df['collection'] == collection)
            )
            i+=1
            resultats = df[filtre]

            if len(resultats) == 0:
                filtre = ((df['collection'] == collection))
                i+=1
                resultats = df[filtre]
    #print(i)
    return resultats['prix'].mean()

# %%
df_zara['matiere'].unique()
# Out:
# array(['fibre artificielle', 'fibre synthétique',
#        'fibre naturelle végétale', 'autres', 'cuir',
#        'fibre naturelle animale'], dtype=object)

# %%
df_zara[(df_zara['collection'] == 'femme') & (df_zara['categorie'] == 'robes')]['prix'].mean()
# Out:
# np.float64(30.46)

# %%
prix_moyen_zara("jupes",'femme', 'vert', 'fibre naturelle végétale')
# Out:
# np.float64(29.95)

# %%
df_vinted['prix_moyen_zara'] = df_vinted.apply(
    lambda ligne: prix_moyen_zara(
        ligne['categorie'],
        ligne['collection'],
        ligne['couleur'],
        ligne['matiere']
    ),
    axis=1
)

df_vinted['decote'] = 1 - df_vinted['prix'] / df_vinted['prix_moyen_zara']

# %%
print(df_vinted.head())
# Out:
#                   etat                      matiere      couleur  \
# 0  neuf sans étiquette  fibres naturelles végétales  blanc/beige
# 1        très bon état  fibres naturelles végétales  blanc/beige
# 2  neuf sans étiquette  fibres naturelles végétales  blanc/beige
# 3  neuf sans étiquette          fibres synthétiques    noir/gris
# 4        très bon état  fibres naturelles végétales  blanc/beige
#
#                categorie  likes  prix  prix_total collection  prix_moyen_zara  \
# 0      hauts et t-shirts   41.0   3.0        3.85      femme           23.325
# 1      hauts et t-shirts   49.0   4.0        4.63      femme           23.325
# 2  pantalons et leggings   24.0  10.0       10.95      femme           35.700
# 3  pantalons et leggings   11.0  15.0       16.38      femme           35.700
# 4      hauts et t-shirts   18.0   6.0        6.61      femme           23.325
#
#      decote
# 0  0.871383
# 1  0.828510
# 2  0.719888
# 3  0.579832
# 4  0.742765

# %%
df_vinted.to_csv("data_final.csv", index=False, encoding="utf-8-sig")
